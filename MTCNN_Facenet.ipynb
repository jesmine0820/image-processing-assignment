# %%
from mtcnn import MTCNN
from keras_facenet import FaceNet
import cv2
import os
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Initialize detector and embedder
detector = MTCNN()
embedder = FaceNet()

def l2_normalize(x):
    return x / np.linalg.norm(x)
# Out:
# WARNING:tensorflow:From c:\Users\User\anaconda3\envs\environment\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
# Folder containing known faces
photo_dir = "photos"

# Get embedding from image path
def get_face_embedding(img_path):
    img = cv2.imread(img_path)
    if img is None:
        print(f"[WARNING] Failed to load image: {img_path}")
        return None
    
    results = detector.detect_faces(img)
    if len(results) == 0:
        print(f"[INFO] No face detected in: {img_path}")
        return None
    
    face = results[0]
    x, y, w, h = face['box']
    x, y = max(0, x), max(0, y)
    
    face_img = img[y:y+h, x:x+w]
    face_img = cv2.resize(face_img, (160, 160))
    
    embedding = embedder.embeddings([face_img])[0]
    embedding = l2_normalize(embedding)
    return embedding

# Build the face database from photo directory
def build_face_database(folder):
    database = {}
    for file in os.listdir(folder):
        if file.lower().endswith(('.jpg', '.jpeg', '.png')):
            path = os.path.join(folder, file)
            name = os.path.splitext(file)[0]
            print(f"Processing: {file}")
            embedding = get_face_embedding(path)
            if embedding is not None:
                database[name] = embedding
            else:
                print(f"[SKIPPED] {file}")
    return database

face_database = build_face_database(photo_dir)
print(f"✅ Loaded {len(face_database)} valid faces from Photo folder.")
# Out:
# Processing: 24WMA08802.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Processing: 24WMA08803.jpg
# [INFO] No face detected in: photos\24WMA08803.jpg
# [SKIPPED] 24WMA08803.jpg
# Processing: 24WMH08807.jpg
# [INFO] No face detected in: photos\24WMH08807.jpg
# [SKIPPED] 24WMH08807.jpg
# Processing: 24WMR08820.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Processing: 24WMR08821.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Processing: 24WMR08822.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Processing: 24WMR08824.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Processing: 24WMR08826.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Processing: 24WMR08827.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Processing: 24WMR08828.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Processing: 24WMR08829.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Processing: 24WMR08831.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Processing: 24WMR08832.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Processing: 24WMR08833.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Processing: 24WMR08834.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Processing: 24WMR08835.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Processing: 24WMR08837.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Processing: 24WMR08838.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Processing: 24WMR08841.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Processing: 24WMR08843.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Processing: 24WMR08861.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Processing: 24WMR08863.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Processing: 24WMR08866.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Processing: 24WMR08870.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ✅ Loaded 22 valid faces from Photo folder.

# %%
# Get top N matches with cosine similarity
def get_top_matches(face_img, database, top_n=3):
    face_img = cv2.resize(face_img, (160, 160))
    embedding = embedder.embeddings([face_img])[0]
    embedding = l2_normalize(embedding)

    similarities = []
    for name, db_emb in database.items():
        sim_score = cosine_similarity([embedding], [db_emb])[0][0]  # Higher is better
        similarities.append((name, sim_score))

    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities[:top_n]

# Start webcam recognition
video = cv2.VideoCapture(0)
print("📷 Press 'q' to quit...")

threshold = 0.7  # Raised threshold

while True:
    ret, frame = video.read()
    if not ret:
        break

    results = detector.detect_faces(frame)
    
    for face in results:
        x, y, w, h = face['box']
        x, y = max(0, x), max(0, y)

        # Add margin to bounding box
        margin = 10
        x1 = max(0, x - margin)
        y1 = max(0, y - margin)
        x2 = min(frame.shape[1], x + w + margin)
        y2 = min(frame.shape[0], y + h + margin)

        face_img = frame[y1:y2, x1:x2]

        top_matches = get_top_matches(face_img, face_database)

        if top_matches and top_matches[0][1] > threshold:
            name = top_matches[0][0]
            similarity = top_matches[0][1]
            cv2.putText(frame, f"{name} ({similarity*100:.1f}%)", (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

            print(f"\nTop 3 matches for face at ({x}, {y}):")
            for match_name, sim in top_matches:
                print(f"  {match_name}: {sim * 100:.2f}% similarity")
        else:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
            print(f"\n❌ No good match found for face at ({x}, {y}).")

    cv2.imshow('Face Recognition with MTCNN + FaceNet', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# 📷 Press 'q' to quit...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#
# Top 3 matches for face at (241, 227):
#   24WMR08866: 77.22% similarity
#   24WMR08863: 52.52% similarity
#   24WMR08861: 51.75% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#
# Top 3 matches for face at (241, 223):
#   24WMR08866: 73.73% similarity
#   24WMR08832: 53.97% similarity
#   24WMR08861: 51.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#
# Top 3 matches for face at (253, 220):
#   24WMR08866: 80.22% similarity
#   24WMR08863: 59.34% similarity
#   24WMR08861: 57.33% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for face at (252, 216):
#   24WMR08866: 74.56% similarity
#   24WMR08863: 57.97% similarity
#   24WMR08861: 52.83% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for face at (243, 223):
#   24WMR08866: 73.41% similarity
#   24WMR08863: 63.74% similarity
#   24WMR08861: 51.53% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# ❌ No good match found for face at (251, 216).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# ❌ No good match found for face at (622, 384).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#
# ❌ No good match found for face at (234, 229).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for face at (238, 225):
#   24WMR08866: 75.86% similarity
#   24WMR08863: 54.56% similarity
#   24WMR08861: 48.59% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Top 3 matches for face at (238, 222):
#   24WMR08866: 74.60% similarity
#   24WMR08861: 53.49% similarity
#   24WMR08863: 50.68% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
#
# Top 3 matches for face at (243, 228):
#   24WMR08866: 72.17% similarity
#   24WMR08861: 52.10% similarity
#   24WMR08863: 48.47% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for face at (242, 223):
#   24WMR08866: 71.11% similarity
#   24WMR08861: 51.89% similarity
#   24WMR08832: 50.25% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for face at (247, 236):
#   24WMR08866: 79.37% similarity
#   24WMR08861: 56.57% similarity
#   24WMR08863: 51.06% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# ❌ No good match found for face at (240, 224).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# ❌ No good match found for face at (238, 224).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# ❌ No good match found for face at (236, 221).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for face at (238, 226):
#   24WMR08866: 77.67% similarity
#   24WMR08863: 57.71% similarity
#   24WMR08832: 53.22% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for face at (241, 224):
#   24WMR08866: 78.82% similarity
#   24WMR08863: 58.95% similarity
#   24WMR08861: 56.73% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
#
# Top 3 matches for face at (243, 216):
#   24WMR08866: 71.16% similarity
#   24WMR08863: 54.33% similarity
#   24WMR08861: 48.19% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Top 3 matches for face at (247, 213):
#   24WMR08866: 70.96% similarity
#   24WMR08863: 56.07% similarity
#   24WMR08835: 46.11% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Top 3 matches for face at (255, 215):
#   24WMR08866: 76.43% similarity
#   24WMR08832: 52.40% similarity
#   24WMR08863: 52.27% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for face at (273, 221):
#   24WMR08866: 73.99% similarity
#   24WMR08863: 56.39% similarity
#   24WMR08861: 49.58% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for face at (281, 216):
#   24WMR08866: 74.85% similarity
#   24WMR08861: 52.34% similarity
#   24WMR08821: 52.19% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Top 3 matches for face at (261, 216):
#   24WMR08866: 74.82% similarity
#   24WMR08832: 55.51% similarity
#   24WMR08821: 52.31% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for face at (255, 225):
#   24WMR08866: 76.57% similarity
#   24WMR08863: 56.69% similarity
#   24WMR08861: 51.24% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
#
# Top 3 matches for face at (257, 222):
#   24WMR08866: 74.31% similarity
#   24WMR08832: 58.32% similarity
#   24WMR08821: 55.89% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Top 3 matches for face at (260, 218):
#   24WMR08866: 74.02% similarity
#   24WMR08832: 54.80% similarity
#   24WMR08863: 52.03% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for face at (257, 215):
#   24WMR08866: 74.66% similarity
#   24WMR08832: 52.38% similarity
#   24WMR08863: 51.62% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# ❌ No good match found for face at (294, 192).
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#
# Top 3 matches for face at (253, 219):
#   24WMR08866: 76.60% similarity
#   24WMR08863: 56.01% similarity
#   24WMR08861: 53.12% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
#
# Top 3 matches for face at (253, 221):
#   24WMR08866: 74.28% similarity
#   24WMR08863: 54.42% similarity
#   24WMR08821: 52.86% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for face at (252, 217):
#   24WMR08866: 73.67% similarity
#   24WMR08832: 56.21% similarity
#   24WMR08821: 55.31% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for face at (252, 218):
#   24WMR08866: 75.72% similarity
#   24WMR08821: 52.62% similarity
#   24WMR08832: 51.71% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for face at (253, 215):
#   24WMR08866: 73.24% similarity
#   24WMR08821: 54.51% similarity
#   24WMR08861: 50.80% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for face at (256, 213):
#   24WMR08866: 74.51% similarity
#   24WMR08863: 53.74% similarity
#   24WMR08861: 53.40% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for face at (256, 214):
#   24WMR08866: 73.75% similarity
#   24WMR08861: 53.84% similarity
#   24WMR08832: 52.44% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for face at (268, 214):
#   24WMR08866: 72.05% similarity
#   24WMR08863: 55.46% similarity
#   24WMR08861: 49.53% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for face at (282, 217):
#   24WMR08866: 71.16% similarity
#   24WMR08863: 54.53% similarity
#   24WMR08861: 50.74% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for face at (286, 218):
#   24WMR08866: 70.51% similarity
#   24WMR08863: 58.40% similarity
#   24WMR08861: 49.47% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for face at (284, 215):
#   24WMR08866: 76.28% similarity
#   24WMR08863: 52.22% similarity
#   24WMR08861: 51.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for face at (283, 218):
#   24WMR08866: 77.85% similarity
#   24WMR08861: 53.60% similarity
#   24WMR08863: 53.42% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Top 3 matches for face at (281, 217):
#   24WMR08866: 73.16% similarity
#   24WMR08861: 55.08% similarity
#   24WMR08863: 53.42% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Top 3 matches for face at (280, 229):
#   24WMR08866: 74.05% similarity
#   24WMR08863: 55.33% similarity
#   24WMR08827: 44.28% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for face at (275, 232):
#   24WMR08866: 80.37% similarity
#   24WMR08863: 56.35% similarity
#   24WMR08827: 49.30% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for face at (271, 228):
#   24WMR08866: 70.52% similarity
#   24WMR08863: 54.11% similarity
#   24WMR08834: 44.47% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for face at (275, 227):
#   24WMR08866: 75.89% similarity
#   24WMR08863: 48.78% similarity
#   24WMR08834: 47.11% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for face at (281, 226):
#   24WMR08866: 79.06% similarity
#   24WMR08861: 52.72% similarity
#   24WMR08863: 50.13% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for face at (285, 221):
#   24WMR08866: 71.16% similarity
#   24WMR08863: 52.67% similarity
#   24WMR08861: 44.13% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for face at (285, 208):
#   24WMR08866: 74.50% similarity
#   24WMR08861: 53.18% similarity
#   24WMR08863: 51.85% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for face at (275, 227):
#   24WMR08866: 75.61% similarity
#   24WMR08863: 53.97% similarity
#   24WMR08861: 45.50% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for face at (275, 228):
#   24WMR08866: 78.10% similarity
#   24WMR08863: 56.72% similarity
#   24WMR08861: 46.53% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for face at (274, 230):
#   24WMR08866: 77.21% similarity
#   24WMR08863: 54.63% similarity
#   24WMR08861: 43.71% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for face at (272, 230):
#   24WMR08866: 78.21% similarity
#   24WMR08863: 59.58% similarity
#   24WMR08861: 50.87% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for face at (272, 232):
#   24WMR08866: 75.97% similarity
#   24WMR08863: 57.65% similarity
#   24WMR08861: 50.21% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for face at (271, 229):
#   24WMR08866: 76.04% similarity
#   24WMR08863: 59.21% similarity
#   24WMR08861: 48.24% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for face at (279, 232):
#   24WMR08866: 76.80% similarity
#   24WMR08863: 57.04% similarity
#   24WMR08827: 47.85% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for face at (288, 230):
#   24WMR08866: 75.99% similarity
#   24WMR08863: 57.37% similarity
#   24WMR08834: 43.54% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Top 3 matches for face at (286, 230):
#   24WMR08866: 76.66% similarity
#   24WMR08863: 60.56% similarity
#   24WMR08861: 47.27% similarity

# %%
from mtcnn import MTCNN
from keras_facenet import FaceNet
import cv2
import os
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Initialize detector and embedder
detector = MTCNN()
embedder = FaceNet()

def l2_normalize(x):
    return x / np.linalg.norm(x)

# Folder containing known faces
photo_dir = "photos"

# Get embedding from image path
def get_face_embedding(img_path):
    img = cv2.imread(img_path)
    if img is None:
        print(f"[WARNING] Failed to load image: {img_path}")
        return None

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = detector.detect_faces(img_rgb)

    if len(results) == 0:
        print(f"[INFO] No face detected in: {img_path}")
        return None

    face = results[0]
    x, y, w, h = face['box']
    x, y = max(0, x), max(0, y)

    face_img = img_rgb[y:y + h, x:x + w]
    face_img = cv2.resize(face_img, (160, 160))

    # Normalize pixel values to [-1, 1]
    face_img = face_img.astype('float32')
    face_img = (face_img - 127.5) / 128.0

    embedding = embedder.embeddings([face_img])[0]
    embedding = l2_normalize(embedding)
    return embedding

# Build the face database from photo directory
def build_face_database(folder):
    database = {}
    for file in os.listdir(folder):
        if file.lower().endswith(('.jpg', '.jpeg', '.png')):
            path = os.path.join(folder, file)
            name = os.path.splitext(file)[0]
            print(f"Processing: {file}")
            embedding = get_face_embedding(path)
            if embedding is not None:
                database[name] = embedding
            else:
                print(f"[SKIPPED] {file}")
    return database

face_database = build_face_database(photo_dir)
print(f"✅ Loaded {len(face_database)} valid faces from Photo folder.")

# Get top N matches with cosine similarity
def get_top_matches(face_img_bgr, database, top_n=3):
    face_img_rgb = cv2.cvtColor(face_img_bgr, cv2.COLOR_BGR2RGB)
    face_img_rgb = cv2.resize(face_img_rgb, (160, 160))
    face_img_rgb = face_img_rgb.astype('float32')
    face_img_rgb = (face_img_rgb - 127.5) / 128.0

    embedding = embedder.embeddings([face_img_rgb])[0]
    embedding = l2_normalize(embedding)

    similarities = []
    for name, db_emb in database.items():
        sim_score = cosine_similarity([embedding], [db_emb])[0][0]
        similarities.append((name, sim_score))

    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities[:top_n]

# Start webcam recognition (only for the nearest/closest face)
video = cv2.VideoCapture(0)
print("📷 Press 'q' to quit...")

threshold = 0.7  # Similarity threshold

while True:
    ret, frame = video.read()
    if not ret:
        break

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = detector.detect_faces(frame_rgb)

    if results:
        # Sort faces by area (width * height), descending
        results.sort(key=lambda face: face['box'][2] * face['box'][3], reverse=True)

        # Process only the closest face (largest bounding box)
        face = results[0]
        x, y, w, h = face['box']
        x, y = max(0, x), max(0, y)

        # Add margin to bounding box
        margin = 10
        x1 = max(0, x - margin)
        y1 = max(0, y - margin)
        x2 = min(frame.shape[1], x + w + margin)
        y2 = min(frame.shape[0], y + h + margin)

        face_img = frame[y1:y2, x1:x2]

        top_matches = get_top_matches(face_img, face_database)

        if top_matches and top_matches[0][1] > threshold:
            name = top_matches[0][0]
            similarity = top_matches[0][1]
            cv2.putText(frame, f"{name} ({similarity*100:.1f}%)", (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

            print(f"\nTop 3 matches for closest face at ({x}, {y}):")
            for match_name, sim in top_matches:
                print(f"  {match_name}: {sim * 100:.2f}% similarity")
        else:
            cv2.putText(frame, "Unknown", (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
            print(f"\n❌ No good match found for closest face at ({x}, {y}).")

    cv2.imshow('Face Recognition (Closest Face Only)', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# Processing: 24WMA08802.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Processing: 24WMA08803.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Processing: 24WMH08807.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Processing: 24WMR08820.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Processing: 24WMR08821.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Processing: 24WMR08822.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Processing: 24WMR08824.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Processing: 24WMR08826.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Processing: 24WMR08827.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Processing: 24WMR08828.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Processing: 24WMR08829.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Processing: 24WMR08831.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Processing: 24WMR08832.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Processing: 24WMR08833.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Processing: 24WMR08834.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Processing: 24WMR08835.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Processing: 24WMR08837.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Processing: 24WMR08838.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Processing: 24WMR08841.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Processing: 24WMR08843.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Processing: 24WMR08861.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Processing: 24WMR08863.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Processing: 24WMR08866.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Processing: 24WMR08870.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ✅ Loaded 24 valid faces from Photo folder.
# 📷 Press 'q' to quit...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Top 3 matches for closest face at (250, 211):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (272, 225):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (284, 222):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (276, 228):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (266, 222):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (262, 214):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (271, 209):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (291, 208):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (300, 211):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (294, 209):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (292, 210):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (290, 213):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (283, 210):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (288, 212):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (285, 207):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (281, 204):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Top 3 matches for closest face at (289, 210):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (290, 211):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Top 3 matches for closest face at (287, 206):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (297, 209):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (298, 207):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Top 3 matches for closest face at (183, 151):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (190, 154):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (215, 158):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Top 3 matches for closest face at (219, 161):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (209, 164):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (219, 161):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (225, 169):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (237, 159):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (237, 172):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (247, 183):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (241, 184):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Top 3 matches for closest face at (237, 187):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (241, 185):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (239, 180):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (240, 185):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (239, 183):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Top 3 matches for closest face at (246, 186):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (246, 187):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (247, 184):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (248, 191):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (230, 196):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (227, 277):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (237, 257):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (250, 250):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (259, 216):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (256, 217):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (267, 213):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (266, 212):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (263, 208):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (275, 203):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (280, 192):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (289, 201):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (296, 203):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (294, 199):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Top 3 matches for closest face at (290, 197):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (290, 199):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (292, 196):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (296, 198):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (296, 195):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (297, 197):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (293, 202):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (296, 194):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (299, 200):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (295, 198):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (297, 198):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (296, 200):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (297, 200):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (305, 209):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (304, 207):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (296, 209):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (286, 214):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (287, 212):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (290, 209):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (302, 215):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (300, 211):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (297, 207):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (297, 208):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (294, 212):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Top 3 matches for closest face at (295, 207):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (293, 209):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (295, 208):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (287, 208):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (282, 217):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (273, 215):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (271, 208):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (277, 205):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (274, 204):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (274, 197):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (274, 196):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (276, 198):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (275, 195):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Top 3 matches for closest face at (276, 198):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Top 3 matches for closest face at (280, 197):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (277, 204):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (295, 202):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
#
# Top 3 matches for closest face at (298, 207):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
#
# Top 3 matches for closest face at (297, 208):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (296, 211):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (286, 209):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (271, 210):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (248, 223):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (218, 228):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (220, 228):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (238, 227):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (253, 220):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (255, 219):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (268, 222):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Top 3 matches for closest face at (273, 220):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (258, 220):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#
# Top 3 matches for closest face at (243, 214):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Top 3 matches for closest face at (213, 284):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#
# Top 3 matches for closest face at (235, 319):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (240, 239):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (241, 249):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (247, 227):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (246, 220):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (235, 221):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (227, 224):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (233, 222):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (235, 221):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (236, 226):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (226, 225):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (226, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (229, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (229, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (242, 227):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (243, 223):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (251, 224):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (249, 226):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (251, 228):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (250, 227):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (245, 223):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (248, 225):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (252, 224):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (253, 219):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Top 3 matches for closest face at (250, 222):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (250, 225):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (236, 224):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (242, 228):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (244, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (236, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (242, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (236, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (234, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (230, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (229, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (228, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (228, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (233, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (223, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (228, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (233, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (233, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (230, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (233, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (230, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (245, 222):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (240, 223):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (237, 221):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (238, 227):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (234, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (233, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (235, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (235, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (236, 238):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (239, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (236, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (235, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (238, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (235, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (237, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (249, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (253, 227):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (252, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (247, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#
# Top 3 matches for closest face at (248, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (242, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (239, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (237, 240):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Top 3 matches for closest face at (233, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (238, 240):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (229, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (230, 237):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (229, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Top 3 matches for closest face at (231, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (228, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (232, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (231, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (230, 239):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (234, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (233, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Top 3 matches for closest face at (231, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (224, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Top 3 matches for closest face at (227, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (230, 227):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (228, 238):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (233, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (227, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (230, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (231, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (226, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (226, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (224, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (228, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (229, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (222, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (225, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Top 3 matches for closest face at (227, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (228, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#
# Top 3 matches for closest face at (230, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (226, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (227, 237):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (228, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (228, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (225, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (231, 237):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Top 3 matches for closest face at (230, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (234, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (231, 240):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (232, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (245, 228):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (264, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (260, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (255, 220):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (242, 218):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (238, 216):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Top 3 matches for closest face at (241, 217):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Top 3 matches for closest face at (243, 219):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
#
# Top 3 matches for closest face at (243, 217):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (231, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (243, 237):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
#
# Top 3 matches for closest face at (245, 237):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
#
# Top 3 matches for closest face at (244, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (247, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (247, 237):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (249, 228):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (252, 226):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#
# Top 3 matches for closest face at (251, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (252, 239):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
#
# Top 3 matches for closest face at (248, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
#
# Top 3 matches for closest face at (254, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (246, 239):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Top 3 matches for closest face at (249, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#
# Top 3 matches for closest face at (242, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (245, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (254, 238):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
#
# Top 3 matches for closest face at (252, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
#
# Top 3 matches for closest face at (254, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
#
# Top 3 matches for closest face at (253, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (247, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
#
# Top 3 matches for closest face at (261, 237):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (248, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (246, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (246, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Top 3 matches for closest face at (246, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Top 3 matches for closest face at (248, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Top 3 matches for closest face at (254, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
#
# Top 3 matches for closest face at (265, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
#
# Top 3 matches for closest face at (275, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (275, 235):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (276, 232):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (269, 231):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Top 3 matches for closest face at (259, 222):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Top 3 matches for closest face at (271, 236):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
#
# Top 3 matches for closest face at (260, 230):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (260, 239):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (263, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (257, 233):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (258, 229):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (270, 238):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
#
# Top 3 matches for closest face at (271, 247):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (263, 243):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
#
# Top 3 matches for closest face at (268, 252):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Top 3 matches for closest face at (271, 248):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (266, 249):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Top 3 matches for closest face at (263, 247):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Top 3 matches for closest face at (261, 252):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (269, 252):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Top 3 matches for closest face at (268, 252):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
#
# Top 3 matches for closest face at (249, 253):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Top 3 matches for closest face at (253, 253):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (252, 252):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#
# Top 3 matches for closest face at (253, 254):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (249, 250):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Top 3 matches for closest face at (257, 244):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#
# Top 3 matches for closest face at (255, 250):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Top 3 matches for closest face at (250, 253):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (247, 254):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Top 3 matches for closest face at (247, 251):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Top 3 matches for closest face at (247, 254):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Top 3 matches for closest face at (248, 254):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (256, 255):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Top 3 matches for closest face at (259, 249):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Top 3 matches for closest face at (261, 243):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
#
# Top 3 matches for closest face at (256, 248):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (261, 252):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (258, 254):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#
# Top 3 matches for closest face at (251, 249):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Top 3 matches for closest face at (252, 252):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Top 3 matches for closest face at (255, 254):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
#
# Top 3 matches for closest face at (257, 237):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (255, 258):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (258, 261):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Top 3 matches for closest face at (256, 253):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (254, 258):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Top 3 matches for closest face at (258, 260):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (258, 261):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
#
# Top 3 matches for closest face at (256, 256):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Top 3 matches for closest face at (255, 258):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
#
# Top 3 matches for closest face at (257, 257):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Top 3 matches for closest face at (261, 255):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Top 3 matches for closest face at (258, 263):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Top 3 matches for closest face at (261, 252):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (261, 249):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (251, 242):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Top 3 matches for closest face at (251, 251):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (240, 250):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Top 3 matches for closest face at (244, 239):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (246, 249):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Top 3 matches for closest face at (251, 238):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Top 3 matches for closest face at (255, 228):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Top 3 matches for closest face at (274, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Top 3 matches for closest face at (286, 234):
#   24WMA08802: 100.00% similarity
#   24WMA08803: 100.00% similarity
#   24WMH08807: 100.00% similarity
